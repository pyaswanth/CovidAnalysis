# %% [markdown]
# <a href="https://colab.research.google.com/github/pyaswanth/CovidAnalysis/blob/main/1st.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import plotly.express as px
import plotly.graph_objects as go
import plotly.figure_factory as ff
from plotly.subplots import make_subplots
import math
import random
from datetime import timedelta
import matplotlib.pyplot as plt
import pandas as pd
import pylab as pl
import numpy as np
df=pd.read_csv("covid_19_india.csv")
df
# Out:
#          Sno        Date     Time  ...    Cured Deaths Confirmed
# 0          1  30-01-2020  6:00 PM  ...        0      0         1
# 1          2  31-01-2020  6:00 PM  ...        0      0         1
# 2          3  01-02-2020  6:00 PM  ...        0      0         2
# 3          4  02-02-2020  6:00 PM  ...        0      0         3
# 4          5  03-02-2020  6:00 PM  ...        0      0         3
# ...      ...         ...      ...  ...      ...    ...       ...
# 18105  18106  11-08-2021  8:00 AM  ...   638410   3831    650353
# 18106  18107  11-08-2021  8:00 AM  ...    77811    773     80660
# 18107  18108  11-08-2021  8:00 AM  ...   334650   7368    342462
# 18108  18109  11-08-2021  8:00 AM  ...  1685492  22775   1708812
# 18109  18110  11-08-2021  8:00 AM  ...  1506532  18252   1534999
#
# [18110 rows x 9 columns]

# %%
# !pip install plotly

# %%
gp_by_date=df.groupby(by=['Date']).sum().reset_index()
gp_by_date.head()
# Out:
#          Date     Sno     Cured  Deaths  Confirmed
# 0  01-01-2021  363618   9883461  148994   10286709
# 1  01-02-2020       3         0       0          2
# 2  01-02-2021  403794  10434983  154392   10756631
# 3  01-03-2020      32         0       0          3
# 4  01-03-2021  440082  10786457  157157   11111149

# %%
gp_by_state=df.groupby(by=['State/UnionTerritory']).sum().reset_index()
gp_by_state
# Out:
#                         State/UnionTerritory      Sno  ...    Deaths   Confirmed
# 0                Andaman and Nicobar Islands  4580097  ...     27136     1938498
# 1                             Andhra Pradesh  4583300  ...   2939367   392432753
# 2                          Arunachal Pradesh  4577248  ...     26799     7176907
# 3                                      Assam  4578837  ...    638323    99837011
# 4                                      Bihar  4583176  ...   1112347   133662075
# 5           Cases being reassigned to states   191339  ...         0      345565
# 6                                 Chandigarh  4584478  ...    147694    10858627
# 7                               Chhattisgarh  4584879  ...   2063920   163776262
# 8                     Dadra and Nagar Haveli    31304  ...         8       20722
# 9   Dadra and Nagar Haveli and Daman and Diu  4512118  ...      1014     1938632
# 10                               Daman & Diu     2891  ...         0           2
# ...

# %%
import matplotlib.pyplot as plt
x=gp_by_state['State/UnionTerritory']
y=gp_by_state['Confirmed']
plt.plot(x,y)
plt.show()

# %%
plt.bar(x,y)
plt.show()

# %%
state_data=df[df['State/UnionTerritory']=='Andhra Pradesh']
per_day_confirmed_cases=state_data['Confirmed'].diff()
state_data['PerDayConfirmed']=per_day_confirmed_cases
state_data
# Out:
#          Sno        Date     Time  ... Deaths Confirmed PerDayConfirmed
# 121      122  12-03-2020  6:00 PM  ...      0         1             NaN
# 134      135  13-03-2020  6:00 PM  ...      0         1             0.0
# 147      148  14-03-2020  6:00 PM  ...      0         1             0.0
# 148      149  15-03-2020  6:00 PM  ...      0         1             0.0
# 162      163  16-03-2020  6:00 PM  ...      0         1             0.0
# ...      ...         ...      ...  ...    ...       ...             ...
# 17931  17932  07-08-2021  8:00 AM  ...  13490   1978350          2209.0
# 17967  17968  08-08-2021  8:00 AM  ...  13513   1980258          1908.0
# 18003  18004  09-08-2021  8:00 AM  ...  13531   1982308          2050.0
# 18039  18040  10-08-2021  8:00 AM  ...  13549   1983721          1413.0
# 18075  18076  11-08-2021  8:00 AM  ...  13564   1985182          1461.0
#
# [518 rows x 10 columns]

# %%
per_day_confirmed_cases=state_data['Confirmed'].diff()
state_data['PerDayConfirmed']=per_day_confirmed_cases
x=state_data['Date']
y=state_data['PerDayConfirmed']
fig = go.Figure()
fig.add_trace(go.Scatter(x=x,y=y))
fig.update_layout(title='Covid cases in Andhra',xaxis_tickfont_size=14,yaxis=dict(title='Number of Cases'))
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="256a101b-f56b-4750-b878-a451607bbdb5" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("256a101b-f56b-4750-b878-a451607bbdb5")) {
#                     Plotly.newPlot(
#                         '256a101b-f56b-4750-b878-a451607bbdb5',
# ...

# %%
fig = go.Figure()
fig.add_trace(go.Scatter(x=x,y=y))
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="5ace5952-bda1-448b-9a3f-37e38b4c1a4d" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("5ace5952-bda1-448b-9a3f-37e38b4c1a4d")) {
#                     Plotly.newPlot(
#                         '5ace5952-bda1-448b-9a3f-37e38b4c1a4d',
# ...

# %%
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#          Sno        Date     Time  ... Deaths Confirmed PerDayConfirmed
# 121      122  12-03-2020  6:00 PM  ...      0         1             NaN
# 134      135  13-03-2020  6:00 PM  ...      0         1             0.0
# 147      148  14-03-2020  6:00 PM  ...      0         1             0.0
# 148      149  15-03-2020  6:00 PM  ...      0         1             0.0
# 162      163  16-03-2020  6:00 PM  ...      0         1             0.0
# ...      ...         ...      ...  ...    ...       ...             ...
# 17931  17932  07-08-2021  8:00 AM  ...  13490   1978350          2209.0
# ...
